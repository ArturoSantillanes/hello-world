# %% [markdown]
# # Ejercicios de optimización escalar

# %% [markdown]
# **Para la siguientes funciones encuentre los puntos críticos, grafique y diga si éste se trata de un máximo o mínimo, local o global.**

# %% [markdown]
# # Arturo Santillanes - 24 de agosto del 2023

# %% [markdown]
# ## Tarea 02

# %% [markdown]
# $f(x)=1260+117x-9x^2$

# %%
import sympy as sp
import numpy as np
sp. var ("x")

def f(x):
    return 1260+117*x-(9*x)**2
df = sp.diff(f(x),x)
pc = sp.solve(df , x)
ddf = sp.diff(df, x)
crit_2da_derivada = ddf.subs (x, pc[0])

if crit_2da_derivada < 0 :
    print("El punto crítico se encuentra en " + str (pc[0]) + " y es un máximo." )
elif crit_2da_derivada > 0 :
    print("El punto crítico se encuentra en *" + str (pc[0]) + " y es un mínimo." )
else:
    print("E1 punto crítico se encuentra en " + str(Pc81) + " y no se puede definir por cniterio de segunda derivada")
import matplotlib.pyplot as plt
# %matplotlib inline

xn = np. linspace(-30,43,1000)

plt.figure(figsize=(4,3))
plt.plot(xn, f(xn))
for c in pc:
    plt.plot(c, f(c), "*r", ms=10)
# Out:
# El punto crítico se encuentra en 13/18 y es un máximo.

# %% [markdown]
# $f(x)=5+x+\frac{4}{x}$, para $x>0$

# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

sp.var("x")

def f(x):
    return 5 + x + 4/x

df = sp.diff(f(x), x)

pc = sp.solve(df, x)

ddf = sp.diff(df, x)

critical_points_info = []

for c in pc:
    crit_2da_derivada = ddf.subs(x, c)
    
    if crit_2da_derivada < 0:
        point_info = (c, "máximo")
    elif crit_2da_derivada > 0:
        point_info = (c, "mínimo")
    else:
        point_info = (c, "punto de inflexión")
    
    critical_points_info.append(point_info)

for c, info in critical_points_info:
    print("El punto crítico se encuentra en", c, "y es un", info)

xn = np.linspace(0.1, 5, 1000)  # Evitar división por cero cerca de x=0

plt.figure(figsize=(6, 4))
plt.plot(xn, f(xn))
for c, _ in critical_points_info:
    plt.plot(c, f(c), "*r", ms=10)

plt.xlabel("x")
plt.ylabel("f(x)")
plt.title("Gráfica de la función f(x)")
plt.grid(True)
plt.show()
# Out:
# El punto crítico se encuentra en -2 y es un máximo
# El punto crítico se encuentra en 2 y es un mínimo

# %% [markdown]
# $f(x)=6-2x+\sqrt{18-2x^2}$, para $-3\leq x\leq 3$

# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

x = sp.symbols('x')

def f(x):
    return 6 - 2*x + sp.sqrt(18 - 2*x**2)

df = sp.diff(f(x), x)

pc = sp.solve(df, x)

ddf = sp.diff(df, x)

critical_points_info = []

for c in pc:
    crit_2da_derivada = ddf.subs(x, c)
    
    if crit_2da_derivada < 0:
        point_info = (c, "máximo")
    elif crit_2da_derivada > 0:
        point_info = (c, "mínimo")
    else:
        point_info = (c, "punto de inflexión")
    
    critical_points_info.append(point_info)

for c, info in critical_points_info:
    print("El punto crítico se encuentra en", c, "y es un", info)

xn = np.linspace(-3, 3, 1000)

plt.figure(figsize=(6, 4))
plt.plot(xn, [f(val) for val in xn])
for c, _ in critical_points_info:
    plt.plot(c, f(c), "*r", ms=10)

plt.xlabel("x")
plt.ylabel("f(x)")
plt.title("Gráfica de la función f(x)")
plt.grid(True)
plt.show()
# Out:
# El punto crítico se encuentra en -sqrt(6) y es un máximo

# %% [markdown]
# $f(x)=\frac{1}{4}x^4+\frac{1}{3}x^3-x^2$ en el intervalo $[-3,1.7]$

# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

x = sp.symbols('x')

def f(x):
    return (1/4)*x**4 + (1/3)*x**3 - x**2

df = sp.diff(f(x), x)

pc = sp.solve(df, x)

ddf = sp.diff(df, x)

critical_points_info = []

for c in pc:
    crit_2da_derivada = ddf.subs(x, c)
    
    if crit_2da_derivada < 0:
        point_info = (c, "máximo")
    elif crit_2da_derivada > 0:
        point_info = (c, "mínimo")
    else:
        point_info = (c, "punto de inflexión")
    
    critical_points_info.append(point_info)

for c, info in critical_points_info:
    print("El punto crítico se encuentra en", c, "y es un", info)

xn = np.linspace(-3, 1.7, 1000)

plt.figure(figsize=(6, 4))
plt.plot(xn, [f(val) for val in xn])
for c, _ in critical_points_info:
    plt.plot(c, f(c), "*r", ms=10)

plt.xlabel("x")
plt.ylabel("f(x)")
plt.title("Gráfica de la función f(x)")
plt.grid(True)
plt.show()
# Out:
# El punto crítico se encuentra en -2.00000000000000 y es un mínimo
# El punto crítico se encuentra en 0.0 y es un máximo
# El punto crítico se encuentra en 1.00000000000000 y es un mínimo

# %% [markdown]
# ---
# # **Resuelva los siguientes problemas usando la librería `SymPy`. Use celdas en `Markdown` para explicar su procedimiento.**

# %% [markdown]
# ## El perímetro de un triángulo isósceles es de $10 cm$. ¿Cuánto deben medir sus lados para que el volumen del cuerpo generado por la rotación del triángulo en torno a su base sea el mayor posible? (Volumen de un cono $= \frac{1}{3}\pi r^2 h$, donde $r$ es el radio de la base y $h$ la altura del cono).

# %%
import sympy as sp

# %% [markdown]
#  Definir las variables que se usarán

# %% [markdown]
# a, b = sp.symbols('a b')

# %% [markdown]
# Poner limite del perímetro

# %%
perimeter_constraint = 2*a + b - 10

# %% [markdown]
# Expresión del volumen del cono

# %%
volume_expression = (sp.pi / 12) * a**3

# %% [markdown]
# Resolver b

# %%
b_in_terms_of_a = sp.solve(perimeter_constraint, b)[0]

# %% [markdown]
# Sustituir b en la expresión del volumen

# %%
volume_expression_substituted = volume_expression.subs(b, b_in_terms_of_a)

# %% [markdown]
# Calcular la derivada con respecto a a

# %%
dv_da = sp.diff(volume_expression_substituted, a)

# %% [markdown]
# Resolver dv/da = 0 para encontrar el valor crítico de a

# %%
critical_a = sp.solve(dv_da, a)

# %% [markdown]
# Evaluar el valor crítico de a en la expresión de b

# %%
critical_b = [b_in_terms_of_a.subs(a, a_val) for a_val in critical_a]

# %% [markdown]
# Calcular el valor del volumen correspondiente al valor crítico de a

# %%
max_volume = volume_expression_substituted.subs([(a, critical_a[0]), (b, critical_b[0])])

# %% [markdown]
# Imprimir los resultados

# %%
print("Valor crítico de a:", critical_a[0])
print("Valor correspondiente de b:", critical_b[0])
print("Volumen máximo:", max_volume)
# Out:
# Valor crítico de a: 0
# Valor correspondiente de b: 10
# Volumen máximo: 0

# %% [markdown]
# ## Disponemos de una barra de aluminio de 6 metros para construir una portería de fútbol. Si queremos que el área de la portería sea máxima, ¿cuánto deben medir los postes y el travesaño?

# %%
import sympy as sp

# %% [markdown]
# Definir símbolos para las dimensiones

# %%
x, y = sp.symbols('x y')

# %% [markdown]
# Longitud total de la barra de aluminio

# %%
longitud_total = 6

# %% [markdown]
# Restricción de longitud: 2x + y = longitud_total

# %%
restriccion_longitud = 2*x + y - longitud_total

# %% [markdown]
# Expresión para el área de la portería

# %%
area_porteria = x * y

# %% [markdown]
# Sustituir y en la restricción de longitud

# %%
y_en_funcion_de_x = sp.solve(restriccion_longitud, y)[0]

# %% [markdown]
# Sustituir y en la expresión del área

# %%
area_en_funcion_de_x = area_porteria.subs(y, y_en_funcion_de_x)

# %% [markdown]
# Calcular la derivada de área con respecto a x

# %%
derivada_area = sp.diff(area_en_funcion_de_x, x)

# %% [markdown]
# Encontrar el valor crítico de x haciendo derivada = 0

# %%
x_critico = sp.solve(derivada_area, x)[0]

# %% [markdown]
# Encontrar el valor correspondiente de y usando la restricción de longitud

# %%
y_critico = y_en_funcion_de_x.subs(x, x_critico)

# %% [markdown]
# Calcular el área máxima usando los valores críticos

# %%
area_maxima = area_en_funcion_de_x.subs(x, x_critico)

# %% [markdown]
# Mostrar los resultados

# %%
print("Longitud de los postes (x):", x_critico)
print("Longitud del travesaño (y):", y_critico)
print("Área máxima de la portería:", area_maxima)
# Out:
# Longitud de los postes (x): 3/2
# Longitud del travesaño (y): 3
# Área máxima de la portería: 9/2
